# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# generation of synthetic dataset
N = 100
a = 1
b = 3

x = np.random.uniform(0, 5, N)
noise = np.random.normal(0, .5, N)
y = a * x + b + noise

plt.grid()
plt.scatter(x, y, marker = '.', color = 'r')

# %%
X = x.reshape(-1, 1)

# %%
x # 1d array
# Out:
# array([4.20926458, 4.57403423, 0.76185833, 2.09950636, 1.61178062,
#        1.8859904 , 2.72723705, 1.19323572, 0.74888737, 2.84165741,
#        1.59648042, 1.93235403, 4.46145845, 2.63221047, 1.17032351,
#        0.63379298, 1.33182799, 4.21979222, 3.93414485, 0.83537933,
#        4.82718794, 0.49487251, 2.93645038, 3.0734147 , 2.26732385,
#        0.90794765, 2.5870087 , 1.01000942, 4.42930716, 0.89587724,
#        2.69226305, 2.41065455, 2.41226989, 2.45560272, 1.12337035,
#        3.92592718, 0.44853178, 4.54429675, 2.98622336, 0.13514895,
#        2.66772153, 4.35542361, 3.93004412, 2.01699546, 2.72347104,
#        1.51332467, 4.42044485, 4.36690356, 2.42425526, 3.44225094,
#        0.24617767, 0.20884042, 2.59703743, 4.86945126, 0.46316178,
#        3.33182891, 3.25804809, 4.3589502 , 3.28421289, 0.81722009,
#        1.9983052 , 0.93966663, 3.85667339, 4.98211556, 4.62723721,
#        2.6624425 , 4.03221168, 3.82065794, 0.15332343, 4.92874254,
#        4.26585158, 0.30648324, 0.47806793, 3.22891924, 4.2485704 ,
#        0.22455329, 3.53626628, 1.44046806, 2.25564637, 0.61555199,
#        2.75085982, 2.45168677, 3.46908843, 2.12381229, 3.54864905,
#        1.43301252, 4.1849015 , 1.44382094, 3.48621169, 2.53807819,
#        1.89516161, 4.41547351, 0.90787117, 0.37886838, 0.91887909,
#        1.60593808, 4.31733426, 4.54898408, 2.43233322, 2.2872879 ])

# %%
X # array where each row is an array to
# Out:
# array([[4.20926458],
#        [4.57403423],
#        [0.76185833],
#        [2.09950636],
#        [1.61178062],
#        [1.8859904 ],
#        [2.72723705],
#        [1.19323572],
#        [0.74888737],
#        [2.84165741],
#        [1.59648042],
#        [1.93235403],
#        [4.46145845],
#        [2.63221047],
#        [1.17032351],
#        [0.63379298],
#        [1.33182799],
#        [4.21979222],
#        [3.93414485],
#        [0.83537933],
#        [4.82718794],
#        [0.49487251],
#        [2.93645038],
#        [3.0734147 ],
#        [2.26732385],
#        [0.90794765],
#        [2.5870087 ],
#        [1.01000942],
#        [4.42930716],
#        [0.89587724],
#        [2.69226305],
#        [2.41065455],
#        [2.41226989],
#        [2.45560272],
#        [1.12337035],
#        [3.92592718],
#        [0.44853178],
#        [4.54429675],
#        [2.98622336],
#        [0.13514895],
#        [2.66772153],
#        [4.35542361],
#        [3.93004412],
#        [2.01699546],
#        [2.72347104],
#        [1.51332467],
#        [4.42044485],
#        [4.36690356],
#        [2.42425526],
#        [3.44225094],
#        [0.24617767],
#        [0.20884042],
#        [2.59703743],
#        [4.86945126],
#        [0.46316178],
#        [3.33182891],
#        [3.25804809],
#        [4.3589502 ],
#        [3.28421289],
#        [0.81722009],
#        [1.9983052 ],
#        [0.93966663],
#        [3.85667339],
#        [4.98211556],
#        [4.62723721],
#        [2.6624425 ],
#        [4.03221168],
#        [3.82065794],
#        [0.15332343],
#        [4.92874254],
#        [4.26585158],
#        [0.30648324],
#        [0.47806793],
#        [3.22891924],
#        [4.2485704 ],
#        [0.22455329],
#        [3.53626628],
#        [1.44046806],
#        [2.25564637],
#        [0.61555199],
#        [2.75085982],
#        [2.45168677],
#        [3.46908843],
#        [2.12381229],
#        [3.54864905],
#        [1.43301252],
#        [4.1849015 ],
#        [1.44382094],
#        [3.48621169],
#        [2.53807819],
#        [1.89516161],
#        [4.41547351],
#        [0.90787117],
#        [0.37886838],
#        [0.91887909],
#        [1.60593808],
#        [4.31733426],
#        [4.54898408],
#        [2.43233322],
#        [2.2872879 ]])

# %%
# a * x + b = y

model = LinearRegression()
model.fit(X, y)
model
# Out:
# LinearRegression()

# %%
a_found = model.coef_[0]
b_found = model.intercept_

# %%
a_found
# Out:
# np.float64(0.9758334432530126)

# %%
b_found
# Out:
# np.float64(3.0901242550608643)
